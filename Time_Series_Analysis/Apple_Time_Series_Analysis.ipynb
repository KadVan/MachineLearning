# %%
import pandas as pd
import numpy as np

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
df_apple =pdr.get_data_yahoo('AAPL')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099584
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094388
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087461
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089625
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092224
# ...                ...         ...         ...         ...         ...
# 2023-08-02  195.039993  195.179993  191.850006  192.580002  192.580002
# 2023-08-03  191.570007  192.369995  190.690002  191.169998  191.169998
# 2023-08-04  185.520004  187.380005  181.919998  181.990005  181.990005
# 2023-08-07  182.130005  183.130005  177.350006  178.850006  178.850006
# 2023-08-08  179.690002  180.270004  177.580002  179.800003  179.800003
#
#                Volume
# Date
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# ...

# %% [markdown]
# q1-# in our dataset apple data give us information about share market records. 10681 rows and 6 attributes in it. in our data there is records from 12 dec. 1980 to till today.

# %%
df_apple.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-08-02  195.039993  195.179993  191.850006  192.580002  192.580002
# 2023-08-03  191.570007  192.369995  190.690002  191.169998  191.169998
# 2023-08-04  185.520004  187.380005  181.919998  181.990005  181.990005
# 2023-08-07  182.130005  183.130005  177.350006  178.850006  178.850006
# 2023-08-08  179.690002  180.270004  177.580002  179.800003  179.800003
#
#                Volume
# Date
# 2023-08-02   50389300
# 2023-08-03   61235200
# 2023-08-04  115799700
# 2023-08-07   97576100
# 2023-08-08   67739800

# %%
df_apple['High'].plot(figsize=(12,6))  #plotting high values of apple graph
# Out:
# <Axes: xlabel='Date'>

# %%
#xlim and y limit
startdate='2022-01-01'
enddate='2023-03-01'
df_apple['High'].plot(xlim=[startdate,enddate],figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_apple['High'].plot(xlim=[startdate,enddate],ylim=[0,900],figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_apple['High'].plot(xlim=[startdate,enddate],ylim=[0,900],figsize=(12,6),ls='--',c='g')
# Out:
# <Axes: xlabel='Date'>

# %%
df_apple.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df_apple.index
# Out:
# DatetimeIndex(['1980-12-12', '1980-12-15', '1980-12-16', '1980-12-17',
#                '1980-12-18', '1980-12-19', '1980-12-22', '1980-12-23',
#                '1980-12-24', '1980-12-26',
#                ...
#                '2023-07-26', '2023-07-27', '2023-07-28', '2023-07-31',
#                '2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-07', '2023-08-08'],
#               dtype='datetime64[ns]', name='Date', length=10753, freq=None)

# %%
index =df_apple.loc[startdate:enddate].index
index
# Out:
# DatetimeIndex(['2022-01-03', '2022-01-04', '2022-01-05', '2022-01-06',
#                '2022-01-07', '2022-01-10', '2022-01-11', '2022-01-12',
#                '2022-01-13', '2022-01-14',
#                ...
#                '2023-02-15', '2023-02-16', '2023-02-17', '2023-02-21',
#                '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-27',
#                '2023-02-28', '2023-03-01'],
#               dtype='datetime64[ns]', name='Date', length=291, freq=None)

# %%
share_open =df_apple.loc[startdate:enddate]['Open']

# %%
share_open
# Out:
# Date
# 2022-01-03    177.830002
# 2022-01-04    182.630005
# 2022-01-05    179.610001
# 2022-01-06    172.699997
# 2022-01-07    172.889999
#                  ...
# 2023-02-23    150.089996
# 2023-02-24    147.110001
# 2023-02-27    147.710007
# 2023-02-28    147.050003
# 2023-03-01    146.830002
# Name: Open, Length: 291, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(index,share_open)

# %%
figure ,axis =plt.subplots()
plt.tight_layout() # Adjust the padding between and around subplots
figure.autofmt_xdate() # preventing overlapping
axis.plot(index,share_open)

# %%
figure ,axis =plt.subplots()
plt.tight_layout() # Adjust the padding between and around subplots
figure.autofmt_xdate() # preventing overlapping
axis.plot(index,share_open)

# %%
from datetime import datetime

# %%
cd=datetime.now() #(yr, month, day,hour, mint ,sec,ms)
cd
# Out:
# datetime.datetime(2023, 8, 9, 8, 10, 58, 599182)

# %%
cd.date()
# Out:
# datetime.date(2023, 8, 9)

# %%
cd.day
# Out:
# 9

# %%
cd.year
# Out:
# 2023

# %%
cd.weekday()
# Out:
# 2

# %% [markdown]
# #Time Resampling

# %%
df_apple.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.099584  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.094388  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.087461  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089625   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092224   73449600

# %%
df_apple.resample('A').mean()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-31    0.136075    0.136461    0.135903    0.135903    0.105446
# 1981-12-31    0.108883    0.109265    0.108548    0.108548    0.084221
# 1982-12-31    0.085446    0.086665    0.084630    0.085459    0.066307
# 1983-12-31    0.167274    0.171085    0.163449    0.167274    0.129786
# 1984-12-31    0.119956    0.122294    0.117642    0.119651    0.092836
# 1985-12-31    0.091057    0.092023    0.089937    0.090233    0.070011
# 1986-12-31    0.144586    0.147048    0.142207    0.144913    0.112436
# 1987-12-31    0.347817    0.355806    0.339820    0.347751    0.270338
# 1988-12-31    0.371034    0.376663    0.365092    0.370884    0.290353
# 1989-12-31    0.371563    0.377679    0.365881    0.371953    0.293969
# 1990-12-31    0.334839    0.341244    0.328725    0.335373    0.267927
# 1991-12-31    0.468318    0.477012    0.459883    0.468701    0.378500
# ...

# %%
df_apple.resample('A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-31    0.113281    0.113281    0.112723    0.112723    0.087461
# 1981-12-31    0.064174    0.064732    0.063616    0.063616    0.049359
# 1982-12-31    0.049665    0.049665    0.049107    0.049107    0.038102
# 1983-12-31    0.079799    0.085938    0.077009    0.079799    0.061915
# 1984-12-31    0.101004    0.101563    0.097656    0.097656    0.075770
# 1985-12-31    0.065290    0.065848    0.064732    0.064732    0.050225
# 1986-12-31    0.098214    0.099330    0.097098    0.098772    0.076636
# 1987-12-31    0.180246    0.183594    0.179129    0.182478    0.141583
# 1988-12-31    0.319196    0.328125    0.316964    0.322545    0.253650
# 1989-12-31    0.301339    0.308036    0.290179    0.301339    0.237627
# 1990-12-31    0.225446    0.236607    0.216518    0.223214    0.178863
# 1991-12-31    0.366071    0.375000    0.359375    0.367188    0.296592
# ...

# %%
df_apple.resample('A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-31    0.160714    0.161272    0.160714    0.160714    0.124696
# 1981-12-31    0.154018    0.155134    0.154018    0.154018    0.119501
# 1982-12-31    0.151228    0.155692    0.147321    0.151228    0.117336
# 1983-12-31    0.280134    0.282366    0.273996    0.280134    0.217353
# 1984-12-31    0.148438    0.153460    0.145089    0.148438    0.115171
# 1985-12-31    0.136719    0.138951    0.136719    0.136719    0.106079
# 1986-12-31    0.194754    0.195871    0.190290    0.195313    0.151541
# 1987-12-31    0.531250    0.533482    0.515625    0.529018    0.411616
# 1988-12-31    0.420759    0.426339    0.415179    0.421875    0.330267
# 1989-12-31    0.444196    0.449777    0.433036    0.443080    0.350165
# 1990-12-31    0.424107    0.426339    0.417411    0.422991    0.337924
# 1991-12-31    0.647321    0.654018    0.625000    0.649554    0.523331
# ...

# %%
df_apple.resample(rule='A').max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_apple.resample(rule='SM').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_apple.resample(rule='QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_apple['Open'].resample(rule='A').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df_apple['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,8))
# Out:
# <Axes: xlabel='Date'>

# %%
df_apple.head(15)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.099584  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.094388  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.087461  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089625   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092224   73449600
# 1980-12-19  0.126116  0.126674  0.126116  0.126116   0.097852   48630400
# 1980-12-22  0.132254  0.132813  0.132254  0.132254   0.102614   37363200
# 1980-12-23  0.137835  0.138393  0.137835  0.137835   0.106945   46950400
# 1980-12-24  0.145089  0.145647  0.145089  0.145089   0.112573   48003200
# 1980-12-26  0.158482  0.159040  0.158482  0.158482   0.122964   55574400
# 1980-12-29  0.160714  0.161272  0.160714  0.160714   0.124696   93161600
# 1980-12-30  0.157366  0.157366  0.156808  0.156808   0.121666   68880000
# ...

# %%
df_apple['High'].rolling(11).max().head(20)
# Out:
# Date
# 1980-12-12         NaN
# 1980-12-15         NaN
# 1980-12-16         NaN
# 1980-12-17         NaN
# 1980-12-18         NaN
# 1980-12-19         NaN
# 1980-12-22         NaN
# 1980-12-23         NaN
# 1980-12-24         NaN
# 1980-12-26         NaN
# 1980-12-29    0.161272
# 1980-12-30    0.161272
# 1980-12-31    0.161272
# 1981-01-02    0.161272
# 1981-01-05    0.161272
# 1981-01-06    0.161272
# 1981-01-07    0.161272
# 1981-01-08    0.161272
# 1981-01-09    0.161272
# 1981-01-12    0.161272
# Name: High, dtype: float64

# %%
df_apple['High'].rolling(5).max().head(20)
# Out:
# Date
# 1980-12-12         NaN
# 1980-12-15         NaN
# 1980-12-16         NaN
# 1980-12-17         NaN
# 1980-12-18    0.128906
# 1980-12-19    0.126674
# 1980-12-22    0.132813
# 1980-12-23    0.138393
# 1980-12-24    0.145647
# 1980-12-26    0.159040
# 1980-12-29    0.161272
# 1980-12-30    0.161272
# 1980-12-31    0.161272
# 1981-01-02    0.161272
# 1981-01-05    0.161272
# 1981-01-06    0.157366
# 1981-01-07    0.155134
# 1981-01-08    0.155134
# 1981-01-09    0.151228
# 1981-01-12    0.144531
# Name: High, dtype: float64

# %%
df_apple['Open:30 days rolling']=df_apple['Open'].rolling(30).mean()

# %%
df_apple['Open:30 days rolling'].head(35)
# Out:
# Date
# 1980-12-12         NaN
# 1980-12-15         NaN
# 1980-12-16         NaN
# 1980-12-17         NaN
# 1980-12-18         NaN
# 1980-12-19         NaN
# 1980-12-22         NaN
# 1980-12-23         NaN
# 1980-12-24         NaN
# 1980-12-26         NaN
# 1980-12-29         NaN
# 1980-12-30         NaN
# 1980-12-31         NaN
# 1981-01-02         NaN
# 1981-01-05         NaN
# 1981-01-06         NaN
# 1981-01-07         NaN
# 1981-01-08         NaN
# 1981-01-09         NaN
# 1981-01-12         NaN
# 1981-01-13         NaN
# 1981-01-14         NaN
# 1981-01-15         NaN
# 1981-01-16         NaN
# 1981-01-19         NaN
# 1981-01-20         NaN
# 1981-01-21         NaN
# 1981-01-22         NaN
# 1981-01-23         NaN
# 1981-01-26    0.140067
# 1981-01-27    0.140588
# 1981-01-28    0.141146
# 1981-01-29    0.141834
# 1981-01-30    0.142225
# 1981-02-02    0.142243
# Name: Open:30 days rolling, dtype: float64

# %%
df_apple.head(35)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.099584  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.094388  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.087461  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089625   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092224   73449600
# 1980-12-19  0.126116  0.126674  0.126116  0.126116   0.097852   48630400
# 1980-12-22  0.132254  0.132813  0.132254  0.132254   0.102614   37363200
# 1980-12-23  0.137835  0.138393  0.137835  0.137835   0.106945   46950400
# 1980-12-24  0.145089  0.145647  0.145089  0.145089   0.112573   48003200
# 1980-12-26  0.158482  0.159040  0.158482  0.158482   0.122964   55574400
# 1980-12-29  0.160714  0.161272  0.160714  0.160714   0.124696   93161600
# 1980-12-30  0.157366  0.157366  0.156808  0.156808   0.121666   68880000
# ...

# %%
df_apple[['Open','Open:30 days rolling']].plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Q no.2- get max price from 2016 to 2023

# %%
#xlim and y limit
startdate='2016-01-01'
enddate='2023-03-01'
df_apple['Close'].plot(xlim=[startdate,enddate])
# Out:
# <Axes: xlabel='Date'>

# %%
share_Close =df_apple.loc[startdate:enddate]['Close']

# %%
share_Close
# Out:
# Date
# 2016-01-04     26.337500
# 2016-01-05     25.677500
# 2016-01-06     25.174999
# 2016-01-07     24.112499
# 2016-01-08     24.240000
#                  ...
# 2023-02-23    149.399994
# 2023-02-24    146.710007
# 2023-02-27    147.919998
# 2023-02-28    147.410004
# 2023-03-01    145.309998
# Name: Close, Length: 1802, dtype: float64

# %%
##closing maximum price ofapple data
share_Close.max()
# Out:
# 182.00999450683594

# %%
#xlim and y limit
startdate='2016-01-01'
enddate='2023-03-01'
df_apple['Close'].plot(xlim=[startdate,enddate],figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #Q 3-Which is the highest price of data

# %%
#xlim and y limit
startdate='2016-01-01'
enddate='2023-08-09'
df_apple['Close'].plot(xlim=[startdate,enddate],figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
##closing maximum price ofapple data
share_Close.max()
# Out:
# 182.00999450683594

# %% [markdown]
# #Q 4-which is the dateof the lowest price of the data?

# %%
##closing maximum price ofapple data
share_Close.min()
# Out:
# 22.584999084472656
